# %%
import os
import numpy as np
import pandas as pd
import matplotlib.dates as dates

# %%
import torch.nn as nn
import torch
embedding = nn.Embedding(10, 3)

input = torch.LongTensor([[1,2,4,5],[4,3,2,9]])
embedding(input)
# Out:
# tensor([[[ 1.6297,  0.0073, -2.4741],
#          [ 1.7235, -1.7851, -0.8534],
#          [ 1.0677,  0.6499,  1.0779],
#          [-0.4261, -0.5555, -0.0344]],
#
#         [[ 1.0677,  0.6499,  1.0779],
#          [-0.0398, -0.4090, -1.4511],
#          [ 1.7235, -1.7851, -0.8534],
#          [-0.5684, -1.0793, -1.8669]]], grad_fn=<EmbeddingBackward>)

# %%
print(input)
# Out:
# tensor([[1, 2, 4, 5],
#         [4, 3, 2, 9]])

# %% [markdown]
# ## check for dataset

# %%
path_data_istabul = 'data/Istanbul Weather Data.csv'

df = pd.read_csv(path_data_istabul)
print(df.shape)
df.head(10)
# Out:
# (3896, 12)
#      DateTime      Condition  Rain  MaxTemp  MinTemp   SunRise    SunSet  \
# 0  2009-01-01  Partly cloudy  0.23        5        2  08:29:00  17:47:00
# 1  2009-01-02       Overcast  4.48        4        1  08:29:00  17:48:00
# 2  2009-01-03       Overcast  0.08        5        3  08:29:00  17:48:00
# 3  2009-01-04           Mist  2.91        5        3  08:29:00  17:49:00
# 4  2009-01-05       Overcast  4.32        5        3  08:29:00  17:50:00
# 5  2009-01-06       Overcast  2.71        5        3  08:29:00  17:51:00
# 6  2009-01-07       Overcast  0.23        7        2  08:29:00  17:52:00
# 7  2009-01-08  Partly cloudy  3.06        8        1  08:29:00  17:53:00
# 8  2009-01-09         Cloudy  1.26        3        0  08:29:00  17:54:00
# 9  2009-01-10          Sunny  0.00        5        0  08:28:00  17:55:00
#
#    MoonRise   MoonSet  AvgWind  AvgHumidity  AvgPressure
# 0   11:9:00  22:39:00       10           90         1027
# 1  11:30:00  23:43:00       12           89         1021
# 2  11:52:00       NaN       16           94         1021
# 3   0:15:00  12:48:00        9           94         1014
# 4   0:41:00   1:57:00       15           97         1015
# 5  13:13:00    3:9:00       22           96         1014
# 6  13:53:00   4:25:00       11           88         1022
# 7  14:44:00   5:41:00       12           88         1024
# 8  15:48:00   6:53:00       23           83         1033
# 9   17:3:00   7:55:00        7           82         1028

# %% [markdown]
# ## Missing value processing

# %%
print("check \n",df.isnull().sum())

#Missing value is delete on colum
df = df.dropna(how='any', axis=1)
print()
print("deleted data\n",df.isnull().sum())
# Out:
# check
#  DateTime         0
# Condition        0
# Rain             0
# MaxTemp          0
# MinTemp          0
# SunRise          0
# SunSet           0
# MoonRise       132
# MoonSet        131
# AvgWind          0
# AvgHumidity      0
# AvgPressure      0
# dtype: int64
#
# deleted data
#  DateTime       0
# Condition      0
# Rain           0
# MaxTemp        0
# MinTemp        0
# SunRise        0
# SunSet         0
# AvgWind        0
# AvgHumidity    0
# AvgPressure    0
# dtype: int64

# %%
df.describe()
# Out:
#               Rain      MaxTemp      MinTemp      AvgWind  AvgHumidity  \
# count  3896.000000  3896.000000  3896.000000  3896.000000  3896.000000
# mean      0.946794    18.084189    13.774897    16.989220    71.414784
# std       2.558308     7.613318     6.865021     7.950417     9.483500
# min       0.000000    -3.000000    -5.000000     2.000000    40.000000
# 25%       0.000000    12.000000     8.000000    11.000000    65.000000
# 50%       0.010000    18.000000    14.000000    16.000000    71.000000
# 75%       0.720000    25.000000    20.000000    22.000000    78.000000
# max      42.000000    37.000000    26.000000    56.000000    97.000000
#
#        AvgPressure
# count  3896.000000
# mean   1015.281314
# std       6.284232
# min     992.000000
# 25%    1011.000000
# 50%    1015.000000
# 75%    1019.000000
# max    1038.000000

# %%
def re_organize(df):
    df['DateTime'] = pd.to_datetime(df['DateTime'])
    df.set_index("DateTime",inplace=True)
    return df
df= re_organize(df)
df
# Out:
#                        Condition  Rain  MaxTemp  MinTemp   SunRise    SunSet  \
# DateTime
# 2009-01-01         Partly cloudy  0.23        5        2  08:29:00  17:47:00
# 2009-01-02              Overcast  4.48        4        1  08:29:00  17:48:00
# 2009-01-03              Overcast  0.08        5        3  08:29:00  17:48:00
# 2009-01-04                  Mist  2.91        5        3  08:29:00  17:49:00
# 2009-01-05              Overcast  4.32        5        3  08:29:00  17:50:00
# ...                          ...   ...      ...      ...       ...       ...
# 2019-08-28         Partly cloudy  0.00       27       23  06:27:00  19:43:00
# 2019-08-29         Partly cloudy  0.00       27       22  06:29:00  19:42:00
# 2019-08-30  Patchy rain possible  0.50       26       22  06:30:00  19:40:00
# 2019-08-31         Partly cloudy  0.00       27       22  06:31:00  19:38:00
# 2019-09-01         Partly cloudy  0.00       27       22  06:32:00  19:37:00
#
#             AvgWind  AvgHumidity  AvgPressure
# DateTime
# 2009-01-01       10           90         1027
# 2009-01-02       12           89         1021
# 2009-01-03       16           94         1021
# 2009-01-04        9           94         1014
# 2009-01-05       15           97         1015
# ...             ...          ...          ...
# 2019-08-28       24           61         1015
# 2019-08-29       20           64         1016
# 2019-08-30       22           63         1015
# 2019-08-31       21           66         1011
# 2019-09-01       23           66         1012
#
# [3896 rows x 9 columns]

# %%
import matplotlib.pyplot as plt

col_vals = ['Rain', 'MaxTemp', 'MinTemp', 'AvgWind', 'AvgHumidity', 'AvgPressure']
col_date = 'DateTime'
nrows = len(col_vals)
width = 16
height = 10

fig, axs = plt.subplots(nrows, 1, figsize=(width, height), facecolor='w')
axs = axs.ravel()
for i, col in enumerate(col_vals):
    axs[i].plot(df["2013":].index, df["2013":][col], marker='o', markersize=2, label='Train')
    axs[i].xaxis.set_major_locator(dates.MonthLocator([1,7]))
    axs[i].xaxis.set_major_formatter(dates.DateFormatter('%Y/%m'))
    axs[i].set_ylabel(col, fontsize=16)

plt.tight_layout()
# plt.xticks(rotation=90)
plt.show()

# %%
from sklearn import datasets
df.corr().style.background_gradient(axis=None)
# Out:
# <style  type="text/css" >
#     #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row0_col1 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row0_col2 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row0_col3 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row0_col4 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row0_col5 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row1_col0 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row1_col2 {
#             background-color:  #034267;
#             color:  #f1f1f1;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row1_col3 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row1_col5 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row2_col0 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row2_col1 {
#             background-color:  #034267;
#             color:  #f1f1f1;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row2_col3 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row2_col4 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row2_col5 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row3_col0 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row3_col1 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row3_col2 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row3_col4 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row3_col5 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row4_col0 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row4_col2 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row4_col3 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row4_col5 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row5_col0 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row5_col1 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row5_col2 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row5_col3 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row5_col4 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row5_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Rain</th>        <th class="col_heading level0 col1" >MaxTemp</th>        <th class="col_heading level0 col2" >MinTemp</th>        <th class="col_heading level0 col3" >AvgWind</th>        <th class="col_heading level0 col4" >AvgHumidity</th>        <th class="col_heading level0 col5" >AvgPressure</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0level0_row0" class="row_heading level0 row0" >Rain</th>
#                         <td id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row0_col1" class="data row0 col1" >-0.144952</td>
#                         <td id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row0_col2" class="data row0 col2" >-0.123754</td>
#                         <td id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row0_col3" class="data row0 col3" >0.155156</td>
#                         <td id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row0_col4" class="data row0 col4" >0.278792</td>
#                         <td id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row0_col5" class="data row0 col5" >-0.153274</td>
#             </tr>
#             <tr>
#                         <th id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0level0_row1" class="row_heading level0 row1" >MaxTemp</th>
#                         <td id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row1_col0" class="data row1 col0" >-0.144952</td>
#                         <td id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row1_col2" class="data row1 col2" >0.946626</td>
#                         <td id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row1_col3" class="data row1 col3" >-0.140458</td>
#                         <td id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row1_col4" class="data row1 col4" >-0.469191</td>
#                         <td id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row1_col5" class="data row1 col5" >-0.436150</td>
#             </tr>
#             <tr>
#                         <th id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0level0_row2" class="row_heading level0 row2" >MinTemp</th>
#                         <td id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row2_col0" class="data row2 col0" >-0.123754</td>
#                         <td id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row2_col1" class="data row2 col1" >0.946626</td>
#                         <td id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row2_col3" class="data row2 col3" >-0.047940</td>
#                         <td id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row2_col4" class="data row2 col4" >-0.371696</td>
#                         <td id="T_38b77026_fb14_11ea_8e4e_3af9d3d471d0row2_col5" class="data row2 col5" >-0.399119</td>
#             </tr>
#             <tr>
#                         <th id="T_38b

# %% [markdown]
# ## normalization

# %%
#import 
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
col_scale = ['Rain', 'MaxTemp', 'MinTemp', 'AvgWind', 'AvgHumidity', 'AvgPressure']
scale=scaler.fit(df.loc[:, col_scale])

transformed = scaler.transform(df.loc[:, col_scale])
# make a trasformed Dataset 
df_transformed = pd.DataFrame(transformed, columns = col_scale)
df_time = pd.DataFrame(df.index)
df_transformed = pd.concat([df_time, df_transformed], axis=1)
df_transformed.head()
# Out:
#     DateTime      Rain  MaxTemp   MinTemp   AvgWind  AvgHumidity  AvgPressure
# 0 2009-01-01  0.005476    0.200  0.225806  0.148148     0.877193     0.760870
# 1 2009-01-02  0.106667    0.175  0.193548  0.185185     0.859649     0.630435
# 2 2009-01-03  0.001905    0.200  0.258065  0.259259     0.947368     0.630435
# 3 2009-01-04  0.069286    0.200  0.258065  0.129630     0.947368     0.478261
# 4 2009-01-05  0.102857    0.200  0.258065  0.240741     1.000000     0.500000

# %% [markdown]
# ## check normalization

# %%
import matplotlib.pyplot as plt
df_transformed= re_organize(df_transformed)
col_vals = ['Rain', 'MaxTemp', 'MinTemp', 'AvgWind', 'AvgHumidity', 'AvgPressure']
col_date = 'DateTime'
nrows = len(col_vals)
width = 16
height = 10

fig, axs = plt.subplots(nrows, 1, figsize=(width, height), facecolor='w')
axs = axs.ravel()
for i, col in enumerate(col_vals):
    axs[i].plot_date(df_transformed["2013":].index, df_transformed["2013":][col], marker='o', markersize=2, label='Train')
    axs[i].xaxis.set_major_locator(dates.MonthLocator([1,7]))
    axs[i].xaxis.set_major_formatter(dates.DateFormatter('%Y/%m'))
    axs[i].set_ylabel(col, fontsize=16)

plt.tight_layout()
# plt.xticks(rotation=90)
plt.show()

# %%
lookback = 120
cols_target = ['Rain', 'MaxTemp', 'MinTemp', 'AvgWind', 'AvgHumidity', 'AvgPressure']

df_train_transformed = df_transformed.reset_index(drop=True)
# df_test_transformed = df_test_transformed.reset_index(drop=True)

x = []
t = []
for i in range(1, len(df)-lookback-1):
    x.append(df_train_transformed.loc[i:i+lookback-1,cols_target].values)
    t.append(df_train_transformed.loc[i+lookback,cols_target].values.tolist())
X_train = np.array(x).reshape(-1, lookback, len(cols_target))
y_train = np.array(t)
print("X_train shape",X_train.shape)
print("y_train shape",y_train.shape)
# Out:
# X_train shape (3774, 120, 6)
# y_train shape (3774, 6)

# %%
#データの分割
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = \
    train_test_split(X_train, y_train, test_size=0.1, shuffle=False)

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

class LSTM(nn.Module):
    def __init__(self, num_classes, input_size, hidden_size, num_layers, initial_normal=False):
        super().__init__()
        self.num_classes = num_classes
        self.num_layers = num_layers
        self.input_size = input_size
        self.hidden_size = hidden_size

        self.lstm = nn.LSTM(input_size=input_size,
                            hidden_size=hidden_size,
                            num_layers=num_layers,
                            batch_first=True,
                            bidirectional=False).to(device)
        self.fc = nn.Linear(in_features=hidden_size,
                            out_features=num_classes).to(device)
        self.fc_mid = nn.Linear(in_features=hidden_size,
                            out_features=hidden_size).to(device)

        if initial_normal:
            nn.init.xavier_normal_(self.lstm.weight_ih_l0)
            nn.init.orthogonal_(self.lstm.weight_hh_l0)

    def forward(self, x):
        h_0 = Variable(torch.zeros(
            self.num_layers, x.size(0), self.hidden_size)).to(device)
        
        c_0 = Variable(torch.zeros(
            self.num_layers, x.size(0), self.hidden_size)).to(device)
        # Propagate input through LSTM
        ula, (h_out, _) = self.lstm(x, (h_0, c_0))
        
        h_out = h_out.view(-1, self.hidden_size)
        
        h_out = self.fc_mid(h_out).to(device)
        
        out = self.fc(h_out).to(device)

#         h, _ = self.lstm(x)
#         out = self.fc(h[:, -1])

        return out

# %%
class EarlyStopping:
    '''
    早期終了 (early stopping)
    '''
    def __init__(self, patience=0, verbose=0):
        self._step = 0
        self._loss = float('inf')
        self.patience = patience
        self.verbose = verbose

    def __call__(self, loss):
        if self._loss < loss:
            self._step += 1
            if self._step > self.patience:
                if self.verbose:
                    print('early stopping')
                return True
        else:
            self._step = 0
            self._loss = loss

        return False

# %%
from sklearn.utils import shuffle
import numpy as np
import torch
import torch.optim as optimizers

np.random.seed(123)
torch.manual_seed(123)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_epochs = 2000
batch_size = 256
n_batches_train = X_train.shape[0] // batch_size + 1
n_batches_val = X_val.shape[0] // batch_size + 1
learning_rate = 0.01

input_size = 6
hidden_size = 100
num_layers = 1

num_classes = 6

hist = {'loss': [], 'val_loss': []}
es = EarlyStopping(patience=10, verbose=1)

model = LSTM(num_classes, input_size, hidden_size, num_layers).to(device)

# criterion = nn.MSELoss()
mse=nn.L1Loss()
optimizer = optimizers.Adam(model.parameters(),lr=0.001)
# optimizer = optimizers.SGD(model.parameters(), lr=0.001, momentum=0.9)
# optimizer = optim.RMSprop(model.parameters(), lr=0.001)
#                             lr=0.001),
#                             betas=(0.9, 0.999), amsgrad=True)


# criterion = torch.nn.MSELoss()    # mean-squared error for regression
# optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
#optimizer = torch.optim.SGD(lstm.parameters(), lr=learning_rate)

# %%
preds_0 = 0
t_0 = 0

def train_step(x, t):

    x = torch.Tensor(x).to(device)
    t = torch.Tensor(t).to(device)
    model.train()
    preds = model(x).to(device)
#     print(preds.shape)
    loss = criterion(preds.view(-1),t.view(-1))
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    return loss, preds

def val_step(x, t):
    x = torch.Tensor(x).to(device)
    t = torch.Tensor(t).to(device)
    model.eval()
    preds = model(x)
    loss = criterion(preds, t)

    return loss, preds

# %% [markdown]
# ## train the LSTM

# %%
# Train the model
for epoch in range(num_epochs):
    train_loss = 0.
    val_loss = 0.
    x_, y_ = shuffle(X_train, y_train)

    for batch in range(n_batches_train):
        start = batch * batch_size
        end = start + batch_size
#         print(start, end)
        loss, _ = train_step(x_[start:end], y_[start:end])
        train_loss += loss.item()

    for batch in range(n_batches_val):
        start = batch * batch_size
        end = start + batch_size
        loss, _ = val_step(X_val[start:end], y_val[start:end])
        val_loss += loss.item()

    train_loss /= n_batches_train
    val_loss /= n_batches_val

    hist['loss'].append(train_loss)
    hist['val_loss'].append(val_loss)

    print('epoch: {}, loss: {:.3}, val_loss: {:.3f}'.format(
        epoch+1,
        train_loss,
        val_loss
    ))

    if es(val_loss):
        break
# Out:
# epoch: 1, loss: 0.117, val_loss: 0.047
# epoch: 2, loss: 0.029, val_loss: 0.024
# epoch: 3, loss: 0.0216, val_loss: 0.022
# epoch: 4, loss: 0.0178, val_loss: 0.014
# epoch: 5, loss: 0.0128, val_loss: 0.011
# epoch: 6, loss: 0.0115, val_loss: 0.011
# epoch: 7, loss: 0.0114, val_loss: 0.011
# epoch: 8, loss: 0.0112, val_loss: 0.011
# epoch: 9, loss: 0.0109, val_loss: 0.010
# epoch: 10, loss: 0.0108, val_loss: 0.011
# epoch: 11, loss: 0.0106, val_loss: 0.011
# epoch: 12, loss: 0.0105, val_loss: 0.010
# epoch: 13, loss: 0.0103, val_loss: 0.010
# epoch: 14, loss: 0.01, val_loss: 0.010
# epoch: 15, loss: 0.00989, val_loss: 0.009
# epoch: 16, loss: 0.00972, val_loss: 0.009
# epoch: 17, loss: 0.00941, val_loss: 0.010
# epoch: 18, loss: 0.00926, val_loss: 0.009
# epoch: 19, loss: 0.00897, val_loss: 0.009
# epoch: 20, loss: 0.00877, val_loss: 0.009
# epoch: 21, loss: 0.0086, val_loss: 0.009
# epoch: 22, loss: 0.00856, val_loss: 0.009
# epoch: 23, loss: 0.00833, val_loss: 0.009
# epoch: 24, loss: 0.00817, val_loss: 0.008
# epoch: 25, loss: 0.0081, val_loss: 0.008
# epoch: 26, loss: 0.00802, val_loss: 0.008
# epoch: 27, loss: 0.00792, val_loss: 0.008
# epoch: 28, loss: 0.00794, val_loss: 0.008
# epoch: 29, loss: 0.00791, val_loss: 0.008
# epoch: 30, loss: 0.00775, val_loss: 0.008
# epoch: 31, loss: 0.00758, val_loss: 0.008
# epoch: 32, loss: 0.00759, val_loss: 0.008
# epoch: 33, loss: 0.00744, val_loss: 0.008
# epoch: 34, loss: 0.00752, val_loss: 0.008
# epoch: 35, loss: 0.00735, val_loss: 0.008
# epoch: 36, loss: 0.0073, val_loss: 0.008
# epoch: 37, loss: 0.00715, val_loss: 0.008
# epoch: 38, loss: 0.00719, val_loss: 0.008
# epoch: 39, loss: 0.00721, val_loss: 0.008
# epoch: 40, loss: 0.00711, val_loss: 0.008
# epoch: 41, loss: 0.00703, val_loss: 0.008
# epoch: 42, loss: 0.00701, val_loss: 0.008
# epoch: 43, loss: 0.00687, val_loss: 0.007
# epoch: 44, loss: 0.00697, val_loss: 0.007
# epoch: 45, loss: 0.00689, val_loss: 0.007
# epoch: 46, loss: 0.00699, val_loss: 0.008
# epoch: 47, loss: 0.00685, val_loss: 0.007
# epoch: 48, loss: 0.00688, val_loss: 0.007
# epoch: 49, loss: 0.00684, val_loss: 0.007
# epoch: 50, loss: 0.0069, val_loss: 0.007
# epoch: 51, loss: 0.00688, val_loss: 0.007
# epoch: 52, loss: 0.00684, val_loss: 0.007
# epoch: 53, loss: 0.00689, val_loss: 0.007
# epoch: 54, loss: 0.00678, val_loss: 0.007
# epoch: 55, loss: 0.00684, val_loss: 0.007
# epoch: 56, loss: 0.00675, val_loss: 0.007
# epoch: 57, loss: 0.00671, val_loss: 0.007
# epoch: 58, loss: 0.00677, val_loss: 0.007
# epoch: 59, loss: 0.00664, val_loss: 0.007
# epoch: 60, loss: 0.0067, val_loss: 0.007
# epoch: 61, loss: 0.00672, val_loss: 0.007
# epoch: 62, loss: 0.00662, val_loss: 0.007
# epoch: 63, loss: 0.00665, val_loss: 0.007
# epoch: 64, loss: 0.0066, val_loss: 0.007
# epoch: 65, loss: 0.00666, val_loss: 0.007
# epoch: 66, loss: 0.00667, val_loss: 0.007
# epoch: 67, loss: 0.00669, val_loss: 0.007
# epoch: 68, loss: 0.00677, val_loss: 0.007
# epoch: 69, loss: 0.0066, val_loss: 0.007
# epoch: 70, loss: 0.00662, val_loss: 0.007
# epoch: 71, loss: 0.00654, val_loss: 0.007
# epoch: 72, loss: 0.00665, val_loss: 0.007
# epoch: 73, loss: 0.00661, val_loss: 0.007
# epoch: 74, loss: 0.00664, val_loss: 0.007
# epoch: 75, loss: 0.00662, val_loss: 0.007
# epoch: 76, loss: 0.00653, val_loss: 0.007
# epoch: 77, loss: 0.00652, val_loss: 0.007
# early stopping

# %% [markdown]
# ## predict rainfall, temp,wind,humidity and pressure

# %%
model.eval()
x_ = torch.Tensor(X_val).to(device)
preds_val = model(x_).data.cpu().numpy()

# %%
df_preds_val = pd.DataFrame(preds_val,columns=['Rain', 'MaxTemp', 'MinTemp', 'AvgWind', 'AvgHumidity', 'AvgPressure'])
df_val = pd.DataFrame(y_val, columns=['Rain', 'MaxTemp', 'MinTemp', 'AvgWind', 'AvgHumidity', 'AvgPressure'])

# %%
df_preds_val
# Out:
#          Rain   MaxTemp   MinTemp   AvgWind  AvgHumidity  AvgPressure
# 0    0.013624  0.800518  0.968792  0.387375     0.364612     0.445459
# 1    0.021295  0.767183  0.943034  0.391864     0.435143     0.429270
# 2    0.015485  0.764014  0.931033  0.306588     0.435029     0.452202
# 3    0.015494  0.774295  0.946216  0.358947     0.430121     0.459483
# 4    0.016988  0.796098  0.966439  0.401374     0.386442     0.429920
# ..        ...       ...       ...       ...          ...          ...
# 373  0.013179  0.789073  0.945898  0.386881     0.407435     0.492335
# 374  0.013749  0.774320  0.932385  0.393566     0.382468     0.497207
# 375  0.016565  0.753033  0.913851  0.363626     0.419337     0.483404
# 376  0.011835  0.745028  0.901280  0.314299     0.420597     0.508263
# 377  0.018067  0.730711  0.890381  0.353902     0.428029     0.487392
#
# [378 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

col_vals = ['Rain', 'MaxTemp', 'MinTemp', 'AvgWind', 'AvgHumidity', 'AvgPressure']
nrows = len(col_vals)
width = 16
height = 10

fig, axs = plt.subplots(nrows, 1, figsize=(width, height), facecolor='w')
axs = axs.ravel()
for i, col in enumerate(col_vals):
    axs[i].plot(df_preds_val.index, df_preds_val[col], marker='o', markersize=2, label='pred')
    axs[i].plot(df_val.index, df_val[col], marker='o', markersize=2, label='label')
    axs[i].set_ylabel(col, fontsize=16)
    axs[i].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## check laerning progress

# %%
plt.plot(range(len(hist["loss"])),hist["loss"],
         color='blue', linestyle='-', label='train_loss')
plt.plot(range(len(hist["val_loss"])), hist["val_loss"],
         color='r', linestyle='-', label='validation_loss')

plt.legend()
plt.grid()
